# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0cdc486b-c87f-4ff2-a921-2ccedc49dea1">Loading BokehJS ...</span>
#     </div>

# %%
from cameo import models
from marsi.cobra.flux_analysis import sensitivity_analysis

# %%
model = models.bigg.iJO1366

# %% [markdown]
# ### Sensitivity analysis for L-Serine
#
# In this example, the ammount of produced serine is increased in steps. The biomass production will decrease with increased accumulation of Serine. This is a scenario where an metabolite analog would compete with Serine and the cell needs to increase the production of Serine to compete for biomass production and enzyme activity.

# %%
ser__L = model.metabolites.ser__L_c

# %%
result = sensitivity_analysis(model, ser__L, is_essential=True, steps=10,
                              biomass=model.reactions.BIOMASS_Ec_iJO1366_core_53p95M)

# %%
result.data_frame
# Out:
#    fraction     ser__L  BIOMASS_Ec_iJO1366_core_53p95M
# 0      0.00   0.000000                        0.982372
# 1      0.11   2.327074                        0.879966
# 2      0.22   4.654149                        0.776675
# 3      0.33   6.981223                        0.673384
# 4      0.44   9.308298                        0.567309
# 5      0.55  11.635373                        0.459727
# 6      0.66  13.962447                        0.352145
# 7      0.77  16.289522                        0.244563
# 8      0.88  18.616597                        0.129905
# 9      0.99  20.943671                        0.010895

# %%
result.plot(width=700, height=500)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="dbe7de99-445e-4348-afde-accb8f3b5690"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#dbe7de99-445e-4348-afde-accb8f3b5690").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dbe7de99-445e-4348-afde-accb8f3b5690");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dbe7de99-445e-4348-afde-accb8f3b5690' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7fae109d-2378-4685-93a9-7ca893dccd31":{"roots":{"references":[{"attributes":{},"id":"70ce9323-4f1a-402c-b15e-33f2a22ba106","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"24b6f2e0-85c2-45d1-9280-6303724b4dd8","subtype":"Figure","type":"Plot"}},"id":"ad446657-1c2b-4920-893e-bc51c9b1d795","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ad446657-1c2b-4920-893e-bc51c9b1d795","type":"PanTool"},{"id":"3c25d33a-5677-4823-9f88-499370fd8675","type":"WheelZoomTool"},{"id":"42c53486-e08c-4e65-8323-f851f6709f51","type":"BoxZoomTool"},{"id":"58d960ae-2346-407b-a2e5-036b40835422","type":"SaveTool"},{"id":"fed49325-a662-4028-b265-14e64b0a4647","type":"ResetTool"},{"id":"992e7581-b1ec-47ea-bb31-a18d6a48a4c2","type":"HelpTool"}]},"id":"0edd5548-83b2-4096-a884-7a544be67110","type":"Toolbar"},{"attributes":{"callback":null,"end":0.9823718127269816},"id":"aef2e898-a689-4b4b-b995-a84f07d537b4","type":"Range1d"},{"attributes":{"callback":null},"id":"3024961d-413c-4a41-b903-13e748f6d9c1","type":"DataRange1d"},{"attributes":{"callback":null},"id":"8810e0e4-d0f5-4d92-9989-957bfd03b7f8","type":"DataRange1d"},{"attributes":{"axis_label":"Growth rate (h-1)","formatter":{"id":"4a424eaf-4566-4577-bb99-4acfef97c416","type":"BasicTickFormatter"},"plot":{"id":"24b6f2e0-85c2-45d1-9280-6303724b4dd8","subtype":"Figure","type":"Plot"},"ticker":{"id":"71fd1db6-0bbb-4498-9777-a416f1fadabf","type":"BasicTicker"},"y_range_name":"growth_rate"},"id":"b5847602-626e-4921-8244-2abdc9cff212","type":"LinearAxis"},{"attributes":{"line_color":{"value":"orange"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c6b4355d-5c6d-467d-8660-1d1b7fce50eb","type":"Line"},{"attributes":{"plot":{"id":"24b6f2e0-85c2-45d1-9280-6303724b4dd8","subtype":"Figure","type":"Plot"}},"id":"992e7581-b1ec-47ea-bb31-a18d6a48a4c2","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,11.000000000000002,22.000000000000004,33.00000000000001,44.00000000000001,55.00000000000001,66.00000000000001,77.00000000000001,88.00000000000001,99.00000000000001],"y":[0.0,2.6445050835164614,5.992404772492577,10.367379062779763,16.407822427225035,25.309330750791165,39.649676726681776,66.60670644896062,143.30931370323933,1922.3016547120544]}},"id":"7981d27e-18fa-41b8-8815-d7919db45356","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"24b6f2e0-85c2-45d1-9280-6303724b4dd8","subtype":"Figure","type":"Plot"}},"id":"fed49325-a662-4028-b265-14e64b0a4647","type":"ResetTool"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8170881e-ea46-4319-9173-76458f077e52","type":"Line"},{"attributes":{"data_source":{"id":"7981d27e-18fa-41b8-8815-d7919db45356","type":"ColumnDataSource"},"glyph":{"id":"c6b4355d-5c6d-467d-8660-1d1b7fce50eb","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"04f9b433-01e9-49c0-ae01-3c9a7a44a523","type":"Line"},"selection_glyph":null},"id":"0ad09b0d-da72-4c08-ac84-939c827b0546","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"70c59eb4-a542-479e-b081-8c185ae62093","type":"LinearAxis"}],"extra_y_ranges":{"growth_rate":{"id":"aef2e898-a689-4b4b-b995-a84f07d537b4","type":"Range1d"}},"left":[{"id":"a9cb1f7d-bc53-4a42-8d56-dc59b16cb553","type":"LinearAxis"}],"plot_height":500,"plot_width":700,"renderers":[{"id":"70c59eb4-a542-479e-b081-8c185ae62093","type":"LinearAxis"},{"id":"8626d0ca-a698-48be-8334-d0e6caf28ddb","type":"Grid"},{"id":"a9cb1f7d-bc53-4a42-8d56-dc59b16cb553","type":"LinearAxis"},{"id":"b2be8288-f1a0-4ce1-9b85-c0594d9a6e7e","type":"Grid"},{"id":"2a04f95e-869a-4054-98a2-5b7862857969","type":"BoxAnnotation"},{"id":"b5847602-626e-4921-8244-2abdc9cff212","type":"LinearAxis"},{"id":"0ad09b0d-da72-4c08-ac84-939c827b0546","type":"GlyphRenderer"},{"id":"13a3dfac-a29e-4fbb-bc03-4145197d4cde","type":"GlyphRenderer"}],"right":[{"id":"b5847602-626e-4921-8244-2abdc9cff212","type":"LinearAxis"}],"title":{"id":"74dcafc6-f ...

# %% [markdown]
# The same analysis can be done with different simulation methods (e.g. lMOMA).

# %%
from cameo.flux_analysis.simulation import lmoma

# %%
result = sensitivity_analysis(model, ser__L, is_essential=True, steps=10, simulation_method=lmoma,
                              biomass=model.reactions.BIOMASS_Ec_iJO1366_core_53p95M)

# %%
result.plot(width=700, height=500)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="39e19495-1027-4cfa-ad65-9de70979dbf9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#39e19495-1027-4cfa-ad65-9de70979dbf9").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("39e19495-1027-4cfa-ad65-9de70979dbf9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '39e19495-1027-4cfa-ad65-9de70979dbf9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b500a935-a060-4796-a4d8-ffc76a57fae9":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9155d255-90ed-4a7a-b148-04a72bdc5320","type":"Line"},{"attributes":{"axis_label":"Accumulation Level (mmol/gDW)","formatter":{"id":"d09bd8a6-7330-4b9c-a035-c4900d16ce12","type":"BasicTickFormatter"},"plot":{"id":"140ecb44-21be-4dd7-9a84-661bc4205390","subtype":"Figure","type":"Plot"},"ticker":{"id":"70df7b0a-1136-4982-859e-e1f130476891","type":"BasicTicker"}},"id":"e1bb7f0d-8773-4189-b50b-03543f9ad931","type":"LinearAxis"},{"attributes":{},"id":"def29b28-43af-43c9-9af3-d5ca8e2f66c8","type":"BasicTicker"},{"attributes":{"below":[{"id":"2555f0e4-1d27-48cf-af72-d650a23dc556","type":"LinearAxis"}],"extra_y_ranges":{"growth_rate":{"id":"19a56798-d420-4513-b92b-2788952dcb27","type":"Range1d"}},"left":[{"id":"e1bb7f0d-8773-4189-b50b-03543f9ad931","type":"LinearAxis"}],"plot_height":500,"plot_width":700,"renderers":[{"id":"2555f0e4-1d27-48cf-af72-d650a23dc556","type":"LinearAxis"},{"id":"1fea5569-912d-449f-991c-79adc1895ca2","type":"Grid"},{"id":"e1bb7f0d-8773-4189-b50b-03543f9ad931","type":"LinearAxis"},{"id":"b975271e-966e-481e-96b1-72a3b4af28d8","type":"Grid"},{"id":"e48b39d4-7cef-4c7a-8baf-38fff59e681f","type":"BoxAnnotation"},{"id":"d5bc5665-1d88-4d0d-80cf-1447490c33af","type":"LinearAxis"},{"id":"27688a43-c919-423b-af19-b06a0d817300","type":"GlyphRenderer"},{"id":"c05a7268-dbcc-45bb-98c4-2e043f7dc9d9","type":"GlyphRenderer"}],"right":[{"id":"d5bc5665-1d88-4d0d-80cf-1447490c33af","type":"LinearAxis"}],"title":{"id":"22c5aa97-4b07-4012-bee6-8904ad9c11ad","type":"Title"},"tool_events":{"id":"d38b1aec-0284-49c6-b897-b01260859708","type":"ToolEvents"},"toolbar":{"id":"c00e16b3-219c-4d74-9197-1d14987978dd","type":"Toolbar"},"toolbar_sticky":false,"x_range":{"id":"afcbcc51-20cb-41c3-b360-1b9ebfa0292e","type":"DataRange1d"},"y_range":{"id":"5a7c7d67-9feb-44da-9a42-73c31068e650","type":"DataRange1d"}},"id":"140ecb44-21be-4dd7-9a84-661bc4205390","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"70df7b0a-1136-4982-859e-e1f130476891","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"140ecb44-21be-4dd7-9a84-661bc4205390","subtype":"Figure","type":"Plot"},"ticker":{"id":"70df7b0a-1136-4982-859e-e1f130476891","type":"BasicTicker"}},"id":"b975271e-966e-481e-96b1-72a3b4af28d8","type":"Grid"},{"attributes":{"plot":{"id":"140ecb44-21be-4dd7-9a84-661bc4205390","subtype":"Figure","type":"Plot"}},"id":"cc8c797c-5965-4967-af6b-8c905d069e43","type":"SaveTool"},{"attributes":{"data_source":{"id":"651eefbb-ee94-4712-8a3d-24cf0e3e5faf","type":"ColumnDataSource"},"glyph":{"id":"a69420e7-3e1d-414c-9975-afd234274acf","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"6c5694e7-1e28-4c77-8daa-f379061f748d","type":"Line"},"selection_glyph":null,"y_range_name":"growth_rate"},"id":"c05a7268-dbcc-45bb-98c4-2e043f7dc9d9","type":"GlyphRenderer"},{"attributes":{},"id":"d09bd8a6-7330-4b9c-a035-c4900d16ce12","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"140ecb44-21be-4dd7-9a84-661bc4205390","subtype":"Figure","type":"Plot"}},"id":"9d01aa36-daca-45c5-8860-1898008fe5f3","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"afcbcc51-20cb-41c3-b360-1b9ebfa0292e","type":"DataRange1d"},{"attributes":{"line_color":{"value":"orange"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd058a07-34c5-4252-a735-b9324e437814","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c5694e7-1e28-4c77-8daa-f379061f748d","type":"Line"},{"attributes":{"plot":null,"text":"ser__L"},"id":"22c5aa97-4b07-4012-bee6-8904ad9c11ad","type":"Title"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a69420e7-3e1d-414c-9975-afd234274acf","type":"Line"},{"attributes":{"plot":{"id":"140ecb44-21be-4dd7-9a84-661bc4205390","subtype":"Figur ...

# %% [markdown]
# ### Sensitivity analysis for Pyruvate
#
# In this example, the pyruvate of succinate is decreased. This is a scenario where the cells are evolved with a toxic compound and the consumption turnover of that compound decreases.

# %%
pyr = model.metabolites.pyr_c

# %%
result = sensitivity_analysis(model, pyr, is_essential=False, steps=10,
                              biomass=model.reactions.BIOMASS_Ec_iJO1366_core_53p95M)

# %%
result.plot(width=700, height=500)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="55aa9422-41d5-4e8f-850b-5e9d30257569"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#55aa9422-41d5-4e8f-850b-5e9d30257569").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55aa9422-41d5-4e8f-850b-5e9d30257569");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55aa9422-41d5-4e8f-850b-5e9d30257569' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5f3c37ac-9a7f-4822-9cfd-ef291d7e20d6":{"roots":{"references":[{"attributes":{},"id":"3b58d16c-4feb-4669-973b-f5f00b45964c","type":"BasicTicker"},{"attributes":{},"id":"5055b6d9-4c99-470b-b045-44070566ff4d","type":"BasicTicker"},{"attributes":{"line_color":{"value":"orange"},"x":{"field":"x"},"y":{"field":"y"}},"id":"76eb0596-5390-4938-9de3-23ab70178cb3","type":"Line"},{"attributes":{"overlay":{"id":"ac8e9ef0-a254-4127-b21e-22489a1ae6e5","type":"BoxAnnotation"},"plot":{"id":"3bc7d070-f4a9-4a26-885f-230698d80796","subtype":"Figure","type":"Plot"}},"id":"436f1046-8562-45f3-b92e-7ed361d3af3c","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"9a286bb2-cae1-4b13-8d0a-caa2ef91209b","type":"ColumnDataSource"},"glyph":{"id":"f73279d3-1a10-46aa-af28-e65c629feb49","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"05e0bf85-805f-44c7-96c4-0b601c562b3e","type":"Line"},"selection_glyph":null,"y_range_name":"growth_rate"},"id":"e0e06fb7-2c48-44cc-98dd-ef4099e36bbb","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"pyr"},"id":"eea7f794-b013-4366-b096-0943917b9dee","type":"Title"},{"attributes":{},"id":"fd577d8b-f984-4b5a-9474-ac2b00a0d2a6","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"84d49e25-cebe-43f3-9523-b688a4dccbc2","type":"LinearAxis"}],"extra_y_ranges":{"growth_rate":{"id":"38137f83-27cf-4561-b322-daed3e3078ae","type":"Range1d"}},"left":[{"id":"ce81db73-9b0e-4891-aaf6-3e93553b9af6","type":"LinearAxis"}],"plot_height":500,"plot_width":700,"renderers":[{"id":"84d49e25-cebe-43f3-9523-b688a4dccbc2","type":"LinearAxis"},{"id":"72360863-d33c-409e-88bd-a45f6b17305a","type":"Grid"},{"id":"ce81db73-9b0e-4891-aaf6-3e93553b9af6","type":"LinearAxis"},{"id":"71b878cc-d7fd-4c1a-8f3b-8ca26b59bc22","type":"Grid"},{"id":"ac8e9ef0-a254-4127-b21e-22489a1ae6e5","type":"BoxAnnotation"},{"id":"e3846765-c535-4870-9c1f-6a0393247161","type":"LinearAxis"},{"id":"70ffc7f0-1293-4dc5-a6b6-29c9d09664b0","type":"GlyphRenderer"},{"id":"e0e06fb7-2c48-44cc-98dd-ef4099e36bbb","type":"GlyphRenderer"}],"right":[{"id":"e3846765-c535-4870-9c1f-6a0393247161","type":"LinearAxis"}],"title":{"id":"eea7f794-b013-4366-b096-0943917b9dee","type":"Title"},"tool_events":{"id":"9441ccf9-e66a-4e98-9999-817e5cead56a","type":"ToolEvents"},"toolbar":{"id":"a70914dd-e257-402f-ad00-8f4ab2d754b0","type":"Toolbar"},"toolbar_sticky":false,"x_range":{"id":"7fc3dbfb-ed50-46ae-8d7e-854523734d88","type":"DataRange1d"},"y_range":{"id":"84a99041-fc47-4d76-9e40-7588398fae10","type":"DataRange1d"}},"id":"3bc7d070-f4a9-4a26-885f-230698d80796","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Inhibition level","formatter":{"id":"0b5da5b8-c095-469f-9da3-d54453348f59","type":"BasicTickFormatter"},"plot":{"id":"3bc7d070-f4a9-4a26-885f-230698d80796","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b58d16c-4feb-4669-973b-f5f00b45964c","type":"BasicTicker"}},"id":"84d49e25-cebe-43f3-9523-b688a4dccbc2","type":"LinearAxis"},{"attributes":{"plot":{"id":"3bc7d070-f4a9-4a26-885f-230698d80796","subtype":"Figure","type":"Plot"}},"id":"82b56b97-9a27-44e4-988c-43b6529cd909","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ac8e9ef0-a254-4127-b21e-22489a1ae6e5","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":0.9823718127272323},"id":"38137f83-27cf-4561-b322-daed3e3078ae","type":"Range1d"},{"attributes":{},"id":"97dd54d7-23ea-416f-b3ff-50bf60367f93","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3bc7d070-f4a9-4a26-885f-230698d80796","subtype":"Figure","type":"Plot"}},"id":"d3c9e83d-0c50-47f8-a1ee-4ebfe7432bb4","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"}, ...

# %%
result = sensitivity_analysis(model, succ, is_essential=False, steps=10, simulation_method=lmoma,
                              biomass=model.reactions.BIOMASS_Ec_iJO1366_core_53p95M)

# %%
result.data_frame
# Out:
#    fraction  pyr  BIOMASS_Ec_iJO1366_core_53p95M
# 0      0.00  0.0                        0.982372
# 1      0.11  0.0                        0.982372
# 2      0.22  0.0                        0.982372
# 3      0.33  0.0                        0.982372
# 4      0.44  0.0                        0.982372
# 5      0.55  0.0                        0.982372
# 6      0.66  0.0                        0.982372
# 7      0.77  0.0                        0.982372
# 8      0.88  0.0                        0.982372
# 9      0.99  0.0                        0.982372
